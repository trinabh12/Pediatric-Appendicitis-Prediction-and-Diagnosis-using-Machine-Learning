# %%
# ==============================
# Core Libraries
# ==============================
import os
import json
import random
import numpy as np
import pandas as pd

# ==============================
# Visualization
# ==============================
import matplotlib.pyplot as plt
import seaborn as sns

# ==============================
# Machine Learning (Scikit-learn)
# ==============================
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_auc_score,
    roc_curve
)
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# ==============================
# Deep Learning (TensorFlow / Keras)
# ==============================
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# *Load Feature Groups for Phase 1*

# %%
with open("training dataset/tabular/engineered_feature_groups.json") as f:
    feature_groups = json.load(f)

# Phase 1 = Tabular-only features
phase1_features = (
    feature_groups["Clinical"] +
    feature_groups["Laboratory"] +
    feature_groups["Demographic / Other"] +
    feature_groups["Scoring"] +
    feature_groups["clinical_derived"] +
    feature_groups["lab_derived"]
)

print("Phase 1 feature count:", len(phase1_features))
print("Sample features:", phase1_features)
# Out:
# Phase 1 feature count: 50
# Sample features: ['Stool:diarrhea', 'Contralateral_Rebound_Tenderness', 'Migratory_Pain', 'Stool:constipation, diarrhea', 'Ipsilateral_Rebound_Tenderness', 'Body_Temperature', 'Stool:normal', 'Peritonitis:generalized', 'Dysuria', 'Lower_Right_Abd_Pain', 'Stool:constipation', 'Coughing_Pain', 'Psoas_Sign', 'Peritonitis:no', 'Nausea', 'Loss_of_Appetite', 'Peritonitis:local', 'Neutrophilia', 'CRP', 'WBC_in_Urine:+++', 'Thrombocyte_Count', 'WBC_in_Urine:+', 'WBC_Count', 'RBC_Count', 'WBC_in_Urine:++', 'Ketones_in_Urine:+', 'Ketones_in_Urine:+++', 'Hemoglobin', 'WBC_in_Urine:no', 'RBC_in_Urine:+', 'RBC_in_Urine:no', 'RBC_in_Urine:+++', 'Neutrophil_Percentage', 'RDW', 'Ketones_in_Urine:no', 'RBC_in_Urine:++', 'Segmented_Neutrophils', 'Ketones_in_Urine:++', 'Age', 'Height', 'Weight', 'BMI', 'Sex', 'Paedriatic_Appendicitis_Score', 'Alvarado_Score', 'Classic_Presentation_Flag', 'Fever_Flag', 'Inflammatory_Triage', 'Left_Shift_Signal', 'High_CRP_Flag']

# %% [markdown]
# *Load Training Data*

# %%
df = pd.read_csv("training dataset/tabular/train_split.csv")

# Target
y_train = df["Diagnosis"]

# Keep only Phase 1 features that exist in dataset
available_features = [f for f in phase1_features if f in df.columns]

X_train = df[available_features]

print("Final feature count used:", len(available_features))
print("Training shape:", X_train.shape)
# Out:
# Final feature count used: 50
# Training shape: (546, 50)

# %% [markdown]
# *Load Validation Data*

# %%
df_val = pd.read_csv("training dataset/tabular/val_split.csv")

y_val = df_val["Diagnosis"]

# Use SAME features as training
X_val = df_val[available_features]

print("Validation shape:", X_val.shape)
# Out:
# Validation shape: (78, 50)

# %% [markdown]
# *Feature Scaling*

# %%
scaler = StandardScaler()

# Fit ONLY on training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform validation data
X_val_scaled = scaler.transform(X_val)

print("Scaled train shape:", X_train_scaled.shape)
print("Scaled val shape:", X_val_scaled.shape)
# Out:
# Scaled train shape: (546, 50)
# Scaled val shape: (78, 50)

# %% [markdown]
# **Define Multi-Layer Perceptron**

# %%
input_dim = X_train_scaled.shape[1]

small_mlp = Sequential([
    Input(shape=(input_dim,)),
    
    Dense(32, activation="relu"),
    Dropout(0.3),
    
    # Clinical embedding layer (for later fusion)
    Dense(16, activation="relu", name="clinical_embedding"),
    
    Dense(1, activation="sigmoid")
])

small_mlp.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)

small_mlp.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         1,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ clinical_embedding (Dense)      │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,177 (8.50 KB)
#  Trainable params: 2,177 (8.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *Training model with Early Stopping*

# %%
early_stop = EarlyStopping(
    monitor="val_auc",
    patience=10,
    mode="max",
    restore_best_weights=True,
    verbose=1
)

history = small_mlp.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=100,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5220 - auc: 0.5157 - loss: 0.7350 - val_accuracy: 0.5641 - val_auc: 0.5904 - val_loss: 0.6781
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6117 - auc: 0.6450 - loss: 0.6473 - val_accuracy: 0.5897 - val_auc: 0.6620 - val_loss: 0.6346
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6648 - auc: 0.7359 - loss: 0.5899 - val_accuracy: 0.6667 - val_auc: 0.7140 - val_loss: 0.6053
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6960 - auc: 0.7657 - loss: 0.5635 - val_accuracy: 0.6282 - val_auc: 0.7320 - val_loss: 0.5911
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7381 - auc: 0.8148 - loss: 0.5156 - val_accuracy: 0.6538 - val_auc: 0.7514 - val_loss: 0.5767
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7363 - auc: 0.8183 - loss: 0.5097 - val_accuracy: 0.6795 - val_auc: 0.7571 - val_loss: 0.5689
# Epoch 7/100
# ...

# %% [markdown]
# *Plotting training curves*

# %%
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# AUC
plt.subplot(1,2,2)
plt.plot(history.history['auc'], label='Train AUC')
plt.plot(history.history['val_auc'], label='Val AUC')
plt.title('AUC over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()

plt.show()
